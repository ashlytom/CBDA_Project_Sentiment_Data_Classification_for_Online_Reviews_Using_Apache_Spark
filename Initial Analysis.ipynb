# %%
# !wget --no-check-certificate \
'https://s3.amazonaws.com/fast-ai-nlp/amazon_review_polarity_csv.tgz' \
-O './amazon_review_polarity_csv.tgz'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2021-04-15 12:53:15--  https://s3.amazonaws.com/fast-ai-nlp/amazon_review_polarity_csv.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.77.126
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.77.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 688339454 (656M) [application/x-tar]
# Saving to: ‘./amazon_review_polarity_csv.tgz’
#
# ./amazon_review_pol 100%[===================&gt;] 656.45M  21.4MB/s    in 31s
#
# 2021-04-15 12:53:46 (21.1 MB/s) - ‘./amazon_review_polarity_csv.tgz’ saved [688339454/688339454]
#
# </div>

# %%
# !tar -xzvf './amazon_review_polarity_csv.tgz'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">amazon_review_polarity_csv/
# amazon_review_polarity_csv/train.csv
# amazon_review_polarity_csv/readme.txt
# amazon_review_polarity_csv/test.csv
# </div>

# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_df = pd.read_csv('amazon_review_polarity_csv/train.csv', header=None, names=('label', 'headline', 'review'))
copy_train_df = train_df.copy()
train_df['label'] = copy_train_df['label'].apply(lambda x: x-1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_df = pd.read_csv('amazon_review_polarity_csv/test.csv', header=None, names=('label', 'headline', 'review'))
copy_test_df = test_df.copy()
test_df['label'] = copy_test_df['label'].apply(lambda x: x-1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(f"No. of training samples = {train_df.shape[0]}")
print(f"No. of testing samples = {test_df.shape[0]}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">No. of training samples = 3600000
# No. of testing samples = 400000
# </div>

# %%
train_df.sample(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#       <th>headline</th>
#       <th>review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3099278</th>
#       <td>1</td>
#       <td>better discription is needed.</td>
#       <td>I was somewhat disappointed that "alto" was no...</td>
#     </tr>
#     <tr>
#       <th>3151587</th>
#       <td>0</td>
#       <td>Disappointing</td>
#       <td>I am not a Wes Craven fan, never saw the origi...</td>
#     </tr>
#     <tr>
#       <th>3542696</th>
#       <td>1</td>
#       <td>A good yarn</td>
#       <td>This was my second book by White and I found i...</td>
#     </tr>
#     <tr>
#       <th>2396009</th>
#       <td>1</td>
#       <td>Strictly Butter Baby!!!!!</td>
#       <td>As usual, Mateo &amp; Matos know and display what ...</td>
#     </tr>
#     <tr>
#       <th>3591237</th>
#       <td>1</td>
#       <td>Steller</td>
#       <td>I dig this album. It is melodic rhythm-driven ...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_df['label'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 1    1800000
# 0    1800000
# Name: label, dtype: int64</div>

# %%
train_df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: label        0
# headline    77
# review       0
# dtype: int64</div>

# %%
train_df.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3600000.0</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.5</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.5</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.5</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
test_df['label'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 1    200000
# 0    200000
# Name: label, dtype: int64</div>

# %%
test_df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: label        0
# headline    10
# review       0
# dtype: int64</div>
